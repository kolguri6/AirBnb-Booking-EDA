# %% [markdown]
# <a href="https://colab.research.google.com/github/kolguri6/AirBnb-Booking-EDA/blob/main/Airbnb_booking_EDA_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#from google.colab import drive
#drive.mount('/content/drive')

# %%
data = pd.read_csv('/content/Airbnb NYC 2019.csv')
Airbnb_df = pd.DataFrame(data)
Airbnb_df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
pd.set_option('display.max_columns',16)  #displays all column names
Airbnb_df.head(30)
# Out:
#       id                                               name  host_id  \
# 0   2539                 Clean & quiet apt home by the park     2787
# 1   2595                              Skylit Midtown Castle     2845
# 2   3647                THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3   3831                    Cozy Entire Floor of Brownstone     4869
# 4   5022   Entire Apt: Spacious Studio/Loft by central park     7192
# 5   5099          Large Cozy 1 BR Apartment In Midtown East     7322
# 6   5121                                    BlissArtsSpace!     7356
# 7   5178                   Large Furnished Room Near B'way      8967
# 8   5203                 Cozy Clean Guest Room - Family Apt     7490
# 9   5238                 Cute & Cozy Lower East Side 1 bdrm     7549
# 10  5295                   Beautiful 1br on Upper West Side     7702
# 11  5441                    Central Manhattan/near Broadway     7989
# 12  5803     Lovely Room 1, Garden, Best Area, Legal rental     9744
# ...

# %%
Airbnb_df.shape # displays the count of rows and columns
# Out:
# (48895, 16)

# %%
Airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
data['last_review'] = pd.to_datetime(data['last_review'], format = '%Y-%m-%d')
data.last_review = data['last_review'].dt.year.astype('object')
data.last_review
# Out:
# 0        1970.0
# 1        1970.0
# 2           NaN
# 3        1970.0
# 4        1970.0
#           ...
# 48890       NaN
# 48891       NaN
# 48892       NaN
# 48893       NaN
# 48894       NaN
# Name: last_review, Length: 48895, dtype: object

# %%
Airbnb_df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
sns.heatmap(Airbnb_df.isnull(), cbar = False)
# Out:
# <Axes: >

# %%
# Dataset Columns
Airbnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
Airbnb_df.describe(include = 'all')
# Out:
#                   id            name       host_id host_name  \
# count   4.889500e+04           48879  4.889500e+04     48874
# unique           NaN           47905           NaN     11452
# top              NaN  Hillside Hotel           NaN   Michael
# freq             NaN              18           NaN       417
# mean    1.901714e+07             NaN  6.762001e+07       NaN
# std     1.098311e+07             NaN  7.861097e+07       NaN
# min     2.539000e+03             NaN  2.438000e+03       NaN
# 25%     9.471945e+06             NaN  7.822033e+06       NaN
# 50%     1.967728e+07             NaN  3.079382e+07       NaN
# 75%     2.915218e+07             NaN  1.074344e+08       NaN
# max     3.648724e+07             NaN  2.743213e+08       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                48895         48895  48895.000000  48895.000000
# unique                   5           221           NaN           NaN
# ...

# %% [markdown]
# #Charts

# %%
#scatter plot
plt.figure(figsize=(10,8))
sns.scatterplot(data=Airbnb_df, x='longitude', y='latitude',hue = 'neighbourhood_group')
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.title('neighbourhood group based on Latitude and Longitude')
plt.show()

# %%
#
neighbourhood_group_d = Airbnb_df['neighbourhood_group'].value_counts()
neighbourhood_group_d = pd.DataFrame(neighbourhood_group_d).reset_index()
neighbourhood_group_d
# Out:
#            index  neighbourhood_group
# 0      Manhattan                21661
# 1       Brooklyn                20104
# 2         Queens                 5666
# 3          Bronx                 1091
# 4  Staten Island                  373

# %%
sns.barplot(data = neighbourhood_group_d, x = 'index', y= 'neighbourhood_group')
plt.xlabel('index')
plt.ylabel('count')
plt.title('Listings in Each Neighbourhood')
plt.show()

# %%
room_type_data=Airbnb_df['room_type'].value_counts()
room_type_data= pd.DataFrame(room_type_data).reset_index()
room_type_data
# Out:
#              index  room_type
# 0  Entire home/apt      25409
# 1     Private room      22326
# 2      Shared room       1160

# %%
sns.barplot(data = room_type_data, x = 'index', y = 'room_type')
plt.xlabel('Index')
plt.ylabel('count')
plt.title('Room Type Distribution')
plt.show()

# %%
sns.countplot(x=Airbnb_df['room_type'],hue=Airbnb_df['neighbourhood_group'])
plt.xlabel('reserved room type')
plt.ylabel('count')
plt.title('Rooms based on cities')
plt.show()

# %%
group_data1.plot(kind='pie',autopct='%1.2f%%')
plt.show()

# %%
group_values = Airbnb_df['neighbourhood_group'].value_counts()
group_values = pd.DataFrame(group_values).reset_index()
group_values
# Out:
#            index  neighbourhood_group
# 0      Manhattan                21661
# 1       Brooklyn                20104
# 2         Queens                 5666
# 3          Bronx                 1091
# 4  Staten Island                  373

# %%
group_values_sort = group_values.sort_values(by = 'index')
group_values_sort
# Out:
#            index  neighbourhood_group
# 3          Bronx                 1091
# 1       Brooklyn                20104
# 0      Manhattan                21661
# 2         Queens                 5666
# 4  Staten Island                  373

# %%
price_dist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                5 non-null      object
#  1   neighbourhood_group  5 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 208.0+ bytes

# %%
group_sum = Airbnb_df.groupby('neighbourhood_group')['price'].sum()
group_sum = pd.DataFrame(group_sum).reset_index()
group_sum
# Out:
#   neighbourhood_group    price
# 0               Bronx    95459
# 1            Brooklyn  2500600
# 2           Manhattan  4264527
# 3              Queens   563867
# 4       Staten Island    42825

# %%
group_sum_sort = group_sum.sort_values(by = 'neighbourhood_group')
group_sum_sort
# Out:
#   neighbourhood_group    price
# 0               Bronx    95459
# 1            Brooklyn  2500600
# 2           Manhattan  4264527
# 3              Queens   563867
# 4       Staten Island    42825

# %%
price_distribution.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   neighbourhood_group  5 non-null      object
#  1   price                5 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 208.0+ bytes

# %%
join = pd.concat([group_values, group_sum], axis=1, join='inner')
join
# Out:
#            index neighbourhood_group neighbourhood_group    price
# 0      Manhattan               21661               Bronx    95459
# 1       Brooklyn               20104            Brooklyn  2500600
# 2         Queens                5666           Manhattan  4264527
# 3          Bronx                1091              Queens   563867
# 4  Staten Island                 373       Staten Island    42825

# %%
sort_join = pd.concat([group_values_sort, group_sum_sort], axis=0)
sort_join
# Out:
#            index neighbourhood_group      price
# 3          Bronx                1091        NaN
# 1       Brooklyn               20104        NaN
# 0      Manhattan               21661        NaN
# 2         Queens                5666        NaN
# 4  Staten Island                 373        NaN
# 0            NaN               Bronx    95459.0
# 1            NaN            Brooklyn  2500600.0
# 2            NaN           Manhattan  4264527.0
# 3            NaN              Queens   563867.0
# 4            NaN       Staten Island    42825.0

# %%
Airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...
